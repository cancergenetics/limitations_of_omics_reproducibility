# %% [markdown]
# ##  Part 1: Compute mRNA-protein correlation for older tumour studies

# %% [markdown]
# **Input:** Transcriptomics and Proteomics data of the tumour studies listed below.
# 1. <a href=https://www.nature.com/articles/nature13438>Colorectal Cancer (2014)</a>
# 2. <a href=https://www.nature.com/articles/nature18003>Breast Cancer (2016)</a>
# 3. <a href=https://linkinghub.elsevier.com/retrieve/pii/S0092-8674(16)30673-0>Ovarian Cancer (2016)</a>
# 4. <a href=https://tinyurl.com/3m8239bk>Colon Cancer (2019)</a>
#
# **Output:** Gene-wise correlation between mRNA and protein abundances

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Note:</b>
# <ul>
# <li> The input data are downloaded from the links specified in data_sources.ipynb </li>
# <li> The transcriptomic and the proteomic data are preprocessed to get a matrix of proteins (rows) and samples (columns)</li>
# <li> The standardised pipeline is applied before computing the mRNA-protein correlation for each study.</li>
# </div>

# %% [markdown]
# #### Import packages

# %%
import os
import numpy as np
import pandas as pd
import standardised_pipeline_utils

# %%
get_data_path = lambda folders, fname: os.path.normpath(os.environ['DATA_PATH']+'/'+'/'.join(folders) +'/'+ fname)
get_local_data_path = lambda folders, fname: os.path.normpath('../local_data/'+'/'.join(folders) +'/'+ fname)

# %% [markdown]
# #### I/O Files

# %%
# Input Files
file_crc_transcriptomics =  get_data_path(['tumour_studies','crc','coadread_tcga_pub'],
                                          'data_RNA_Seq_expression_median.txt')
file_crc_proteomics = get_data_path(['tumour_studies','crc', 'zhang_2014'], 'Supplemental_Table.xlsx')

file_brca_transcriptomics = get_data_path(['tumour_studies','brca', 'brca_tcga_pub2015'], 
                                          'data_RNA_Seq_v2_expression_median.txt')
file_brca_proteomics = get_data_path(['tumour_studies','brca', 'mertins_2016'], 'CPTAC_BC_SupplementaryTable03.xlsx')

file_ovca_transcriptomics = get_data_path(['tumour_studies','ovca', 'firebrowse'], 'OV.medianexp.txt')
file_ovca_proteomics = get_data_path(['tumour_studies','ovca', 'zhang_2016'], 'Table_S2.xlsx')

file_colon_transcriptomics = get_data_path(['tumour_studies','colon', 'vasaikar_2019'], 'RNAseq.cct')
file_colon_proteomics = get_data_path(['tumour_studies','colon', 'vasaikar_2019'], 'Proteome_TMT.cct')
file_colon_proteomics_lf = get_data_path(['tumour_studies','colon', 'vasaikar_2019'], 'Proteome_LF.cct')

                 
# Output File
file_tumour_correlation = get_local_data_path(['processed', 'correlation_mRNA_protein'], 'older_tumour_studies.csv')
file_samples_info = get_local_data_path(['processed', 'correlation_mRNA_protein'], 'samples_info.csv')

# %%
# Information collected for the Supplemental Table S1B
common_samples = {}
common_genes = {}
transcriptomic_samples = {}
proteomic_samples = {}

# %%
# Pre-processing the data before applying the standardised pipeline
def preprocess(dataframe, index_col, columns_to_drop=[]):
    dataframe = dataframe.dropna(subset=[index_col]).set_index(index_col)
    dataframe.drop(columns_to_drop, axis=1, inplace=True)
    # choose the first 12 characters to identify the patient id
    # that is consistent across transcriptomic and proteomic data
    dataframe.rename(columns= lambda x: str(x)[:12], inplace=True)
    dataframe = dataframe.apply(pd.to_numeric)
    print("Dimensions: ", dataframe.shape)
    print("Null values count: ", dataframe.isnull().sum().sum())
    return dataframe

# %% [markdown]
# <a id="ColoRectal_Cancer"></a>
# ### 1. ColoRectal Cancer

# %% [markdown]
# #### Transcriptomic Data

# %%
# colorectal cancer transcriptomics data
crc_transcriptomics = pd.read_csv(file_crc_transcriptomics, sep='\t',  low_memory=False)
print('Dimensions: ', crc_transcriptomics.shape)
crc_transcriptomics[:1]
# Out:
# Dimensions:  (19489, 246)
#   Hugo_Symbol  Entrez_Gene_Id  TCGA-A6-2670-01  TCGA-A6-2671-01  \
# 0        A1BG               1         0.523167         0.371355
#
#    TCGA-A6-2672-01  TCGA-A6-2674-01  TCGA-A6-2676-01  TCGA-A6-2677-01  \
# 0         0.925661         0.750148         0.524965         0.045138
#
#    TCGA-A6-2678-01  TCGA-A6-2679-01  ...  TCGA-AY-4071-01  TCGA-AZ-4308-01  \
# 0         0.163163         2.267252  ...         0.960731         0.988869
#
#    TCGA-AZ-4313-01  TCGA-AZ-4315-01  TCGA-AZ-4614-01  TCGA-AZ-4615-01  \
# 0         0.285177         0.419773         0.134522         0.337758
#
#    TCGA-AZ-4684-01  TCGA-CA-5256-01  TCGA-CK-4951-01  TCGA-CM-4747-01
# 0         0.714598         0.808955         0.308311         0.718461
#
# [1 rows x 246 columns]

# %%
#Clean data
crc_transcriptomics = preprocess(crc_transcriptomics, index_col='Hugo_Symbol', columns_to_drop=['Entrez_Gene_Id'])
crc_transcriptomics[:2]
# Out:
# Dimensions:  (19489, 244)
# Null values count:  0
#              TCGA-A6-2670  TCGA-A6-2671  TCGA-A6-2672  TCGA-A6-2674  \
# Hugo_Symbol
# A1BG             0.523167      0.371355      0.925661      0.750148
# A1CF             3.269805      0.240150      0.297705      1.956353
#
#              TCGA-A6-2676  TCGA-A6-2677  TCGA-A6-2678  TCGA-A6-2679  \
# Hugo_Symbol
# A1BG             0.524965      0.045138      0.163163      2.267252
# A1CF             1.960370      4.923709      4.173823      1.151729
#
#              TCGA-A6-2680  TCGA-A6-2681  ...  TCGA-AY-4071  TCGA-AZ-4308  \
# Hugo_Symbol                              ...
# A1BG             0.556225      0.619890  ...      0.960731      0.988869
# A1CF             4.542303      1.670868  ...      4.423130      1.619616
#
#              TCGA-AZ-4313  TCGA-AZ-4315  TCGA-AZ-4614  TCGA-AZ-4615  \
# Hugo_Symbol
# A1BG             0.285177      0.419773      0.134522      0.337758
# A1CF             0.201777      0.459658      4.037968      0.412526
#
#              TCGA-AZ-4684  TCGA-CA-5256  TCGA-CK-4951  TCGA-CM-4747
# Hugo_Symbol
# A1BG             0.714598      0.808955      0.308311      0.718461
# A1CF             2.298243      4.482096      0.433493      1.821577
#
# [2 rows x 244 columns]

# %%
assert len(crc_transcriptomics.columns[crc_transcriptomics.columns.duplicated()]) == 0, "columns contain duplicates"

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Note:</b> The older transcriptomic and proteomic data such as this contain 0s and no null values. In such cases, the standardised pipeline obtains proteins where the number of 0s is not measured in >20% of the samples.
# </div>

# %%
#eliminate rows with >20% of null/zero values and compute mean for the isoforms 
crc_transcriptomics_processed = standardised_pipeline_utils.process(crc_transcriptomics)
crc_transcriptomics_processed[:2]
# Out:
# Dimensions:  (15961, 244)
#              TCGA-A6-2670  TCGA-A6-2671  TCGA-A6-2672  TCGA-A6-2674  \
# Hugo_Symbol
# A1BG             0.523167      0.371355      0.925661      0.750148
# A1CF             3.269805      0.240150      0.297705      1.956353
#
#              TCGA-A6-2676  TCGA-A6-2677  TCGA-A6-2678  TCGA-A6-2679  \
# Hugo_Symbol
# A1BG             0.524965      0.045138      0.163163      2.267252
# A1CF             1.960370      4.923709      4.173823      1.151729
#
#              TCGA-A6-2680  TCGA-A6-2681  ...  TCGA-AY-4071  TCGA-AZ-4308  \
# Hugo_Symbol                              ...
# A1BG             0.556225      0.619890  ...      0.960731      0.988869
# A1CF             4.542303      1.670868  ...      4.423130      1.619616
#
#              TCGA-AZ-4313  TCGA-AZ-4315  TCGA-AZ-4614  TCGA-AZ-4615  \
# Hugo_Symbol
# A1BG             0.285177      0.419773      0.134522      0.337758
# A1CF             0.201777      0.459658      4.037968      0.412526
#
#              TCGA-AZ-4684  TCGA-CA-5256  TCGA-CK-4951  TCGA-CM-4747
# Hugo_Symbol
# A1BG             0.714598      0.808955      0.308311      0.718461
# A1CF             2.298243      4.482096      0.433493      1.821577
#
# [2 rows x 244 columns]

# %%
# suppress warnings while reading the colorectal proteomics file 
import warnings 
warnings.simplefilter("ignore", category=UserWarning)

# %% [markdown]
# #### Proteomic Data

# %%
# colorectal cancer proteomics data
crc_proteomics = pd.read_excel(file_crc_proteomics, sheet_name="S4_sample95_count_quantilelog", engine='openpyxl')
print('Dimensions: ', crc_proteomics.shape)
crc_proteomics[:1]
# Out:
# Dimensions:  (7211, 96)
#   GeneSymbol  TCGA-A6-3807-01A-22  TCGA-A6-3808-01A-22  TCGA-A6-3810-01A-22  \
# 0       A1BG             3.168237              4.53212             4.460122
#
#    TCGA-AA-3518-01A-11  TCGA-AA-3525-01A-12  TCGA-AA-3526-01A-11  \
# 0             4.638684             3.161463             3.740757
#
#    TCGA-AA-3529-01A-12  TCGA-AA-3531-01A-22  TCGA-AA-3534-01A-22  ...  \
# 0             3.250323             3.463567             4.249525  ...
#
#    TCGA-AG-A01L-01A-22  TCGA-AG-A01N-01A-23  TCGA-AG-A01W-01A-23  \
# 0             3.598817             2.640816              3.68281
#
#    TCGA-AG-A01Y-01A-43  TCGA-AG-A020-01A-23  TCGA-AG-A026-01A-71  \
# 0             4.406709             3.753199             3.735066
#
#    TCGA-AG-A02N-01A-31  TCGA-AG-A02X-01A-32  TCGA-AG-A032-01A-31  \
# 0             3.471804             4.367886             2.514953
#
#    TCGA-AG-A036-01A-22
# 0             4.111383
#
# [1 rows x 96 columns]

# %%
# Clean data
crc_proteomics = preprocess(crc_proteomics, index_col='GeneSymbol')
crc_proteomics[:2]
# Out:
# Dimensions:  (7211, 95)
# Null values count:  0
#             TCGA-A6-3807  TCGA-A6-3808  TCGA-A6-3810  TCGA-AA-3518  \
# GeneSymbol
# A1BG            3.168237       4.53212      4.460122      4.638684
# A1CF            1.549085       0.00000      1.178337      0.000000
#
#             TCGA-AA-3525  TCGA-AA-3526  TCGA-AA-3529  TCGA-AA-3531  \
# GeneSymbol
# A1BG            3.161463      3.740757      3.250323      3.463567
# A1CF            0.000000      0.889576      0.000000      2.485427
#
#             TCGA-AA-3534  TCGA-AA-3552  ...  TCGA-AG-A01L  TCGA-AG-A01N  \
# GeneSymbol                              ...
# A1BG            4.249525      3.482712  ...      3.598817      2.640816
# A1CF            1.864773      0.000000  ...      0.992387      2.381429
#
#             TCGA-AG-A01W  TCGA-AG-A01Y  TCGA-AG-A020  TCGA-AG-A026  \
# GeneSymbol
# A1BG            3.682810      4.406709      3.753199      3.735066
# A1CF            1.796467      0.000000      2.297423      2.297423
#
#             TCGA-AG-A02N  TCGA-AG-A02X  TCGA-AG-A032  TCGA-AG-A036
# GeneSymbol
# A1BG            3.471804      4.367886      2.514953      4.111383
# A1CF            0.992387      0.000000      1.144390      2.102570
#
# [2 rows x 95 columns]

# %%
assert len(crc_proteomics.columns[crc_proteomics.columns.duplicated()]) == 5, "columns contain no duplicates"

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Note:</b> Since the Colorectal cancer proteomics data contains 5 duplicated sample IDs, drop the duplicated sample IDs. The same procedure is followed for the other studies too in this context.
# </div>

# %%
crc_proteomics = crc_proteomics.loc[:, ~crc_proteomics.columns.duplicated(keep='first')]

# %%
#eliminate rows with >20% of null/zero values
crc_proteomics_processed = standardised_pipeline_utils.process(crc_proteomics)
crc_proteomics_processed[:2]
# Out:
# Dimensions:  (3506, 90)
#             TCGA-A6-3807  TCGA-A6-3808  TCGA-A6-3810  TCGA-AA-3518  \
# GeneSymbol
# A1BG            3.168237       4.53212      4.460122      4.638684
# A2M             7.194187       7.74494      6.507127      7.973176
#
#             TCGA-AA-3525  TCGA-AA-3526  TCGA-AA-3529  TCGA-AA-3531  \
# GeneSymbol
# A1BG            3.161463      3.740757      3.250323      3.463567
# A2M             6.890216      6.481183      6.177288      6.364757
#
#             TCGA-AA-3534  TCGA-AA-3552  ...  TCGA-AG-A01L  TCGA-AG-A01N  \
# GeneSymbol                              ...
# A1BG            4.249525      3.482712  ...      3.598817      2.640816
# A2M             7.194187      6.616646  ...      6.219169      5.679850
#
#             TCGA-AG-A01W  TCGA-AG-A01Y  TCGA-AG-A020  TCGA-AG-A026  \
# GeneSymbol
# A1BG            3.682810      4.406709      3.753199      3.735066
# A2M             6.976798      6.289679      6.815130      5.924375
#
#             TCGA-AG-A02N  TCGA-AG-A02X  TCGA-AG-A032  TCGA-AG-A036
# GeneSymbol
# A1BG            3.471804      4.367886      2.514953      4.111383
# A2M             5.876065      6.704523      6.574803      6.161251
#
# [2 rows x 90 columns]

# %%
transcriptomic_samples['CRC (2014)'] = crc_transcriptomics_processed.shape[1]
proteomic_samples['CRC (2014)'] = crc_proteomics_processed.shape[1]

# %%
crc_transcriptomics_processed, crc_proteomics_processed = standardised_pipeline_utils.match_proteins_samples( \
                                                                            crc_transcriptomics_processed, 
                                                                            crc_proteomics_processed)
# Out:
# Number of common proteins:  3238
# Number of common samples:  77

# %%
common_samples['CRC (2014)'] = crc_transcriptomics_processed.shape[1]
common_genes['CRC (2014)'] = crc_transcriptomics_processed.shape[0]

# %%
correlation_crc = standardised_pipeline_utils.correlate_genewise(crc_transcriptomics_processed, 
                                                                 crc_proteomics_processed, 'CRC (2014)')
# Out:
# Median Spearman Correlation:  0.22

# %% [markdown]
# <a id="Breast_Cancer"></a>
# ### 2. Breast Cancer (2016)

# %% [markdown]
# #### Transcriptomic Data

# %%
brca_transcriptomics = pd.read_csv(file_brca_transcriptomics, sep='\t')
print('Dimensions: ', brca_transcriptomics.shape)
brca_transcriptomics[:1]
# Out:
# Dimensions:  (20440, 819)
#   Hugo_Symbol  Entrez_Gene_Id  TCGA-A1-A0SB-01  TCGA-A1-A0SD-01  \
# 0    UBE2Q2P2       100134869          14.3935          11.3241
#
#    TCGA-A1-A0SE-01  TCGA-A1-A0SF-01  TCGA-A1-A0SH-01  TCGA-A1-A0SI-01  \
# 0           4.4426          10.7401           3.0048           2.9782
#
#    TCGA-A1-A0SJ-01  TCGA-A1-A0SK-01  ...  TCGA-LL-A5YM-01  TCGA-LL-A5YN-01  \
# 0           4.9419           28.856  ...              0.0           2.9624
#
#    TCGA-LL-A5YO-01  TCGA-LL-A5YP-01  TCGA-LQ-A4E4-01  TCGA-MS-A51U-01  \
# 0           3.6899            6.302          14.1288           7.9343
#
#    TCGA-OL-A66H-01  TCGA-OL-A66I-01  TCGA-OL-A66J-01  TCGA-OL-A66K-01
# 0           2.2519           1.2603           5.0428           4.3892
#
# [1 rows x 819 columns]

# %%
#Clean data
brca_transcriptomics = preprocess(brca_transcriptomics, index_col='Hugo_Symbol', columns_to_drop=['Entrez_Gene_Id'])
brca_transcriptomics[:2]
# Out:
# Dimensions:  (20440, 817)
# Null values count:  0
#              TCGA-A1-A0SB  TCGA-A1-A0SD  TCGA-A1-A0SE  TCGA-A1-A0SF  \
# Hugo_Symbol
# UBE2Q2P2          14.3935       11.3241        4.4426       10.7401
# HMGB1P1          116.3870       60.2630      153.1452      141.1933
#
#              TCGA-A1-A0SH  TCGA-A1-A0SI  TCGA-A1-A0SJ  TCGA-A1-A0SK  \
# Hugo_Symbol
# UBE2Q2P2           3.0048        2.9782        4.9419       28.8560
# HMGB1P1           79.8003       63.5491      134.8733     1119.1932
#
#              TCGA-A1-A0SM  TCGA-A1-A0SN  ...  TCGA-LL-A5YM  TCGA-LL-A5YN  \
# Hugo_Symbol                              ...
# UBE2Q2P2           7.6484        5.6992  ...        0.0000        2.9624
# HMGB1P1          119.4760       95.0898  ...      101.2865      100.3083
#
#              TCGA-LL-A5YO  TCGA-LL-A5YP  TCGA-LQ-A4E4  TCGA-MS-A51U  \
# Hugo_Symbol
# UBE2Q2P2           3.6899        6.3020       14.1288        7.9343
# HMGB1P1          278.5626      206.4376      117.0300      150.6834
#
#              TCGA-OL-A66H  TCGA-OL-A66I  TCGA-OL-A66J  TCGA-OL-A66K
# Hugo_Symbol
# UBE2Q2P2           2.2519        1.2603        5.0428        4.3892
# HMGB1P1          115.3378      158.3599      124.6327      106.3475
#
# [2 rows x 817 columns]

# %%
assert len(brca_transcriptomics.columns[brca_transcriptomics.columns.duplicated()]) == 0, \
       "columns contain duplicates"

# %%
brca_transcriptomics_processed = standardised_pipeline_utils.process(brca_transcriptomics)
brca_transcriptomics_processed[:2]
# Out:
# Dimensions:  (16558, 817)
#              TCGA-A1-A0SB  TCGA-A1-A0SD  TCGA-A1-A0SE  TCGA-A1-A0SF  \
# Hugo_Symbol
# A1BG              49.1992      142.2976      192.8194      326.0194
# A1BG-AS1          75.0039      143.6440      148.6170      187.2980
#
#              TCGA-A1-A0SH  TCGA-A1-A0SI  TCGA-A1-A0SJ  TCGA-A1-A0SK  \
# Hugo_Symbol
# A1BG             180.3235      128.4550      226.7801       86.6436
# A1BG-AS1         157.7045      147.4985      115.2922       65.2821
#
#              TCGA-A1-A0SM  TCGA-A1-A0SN  ...  TCGA-LL-A5YM  TCGA-LL-A5YN  \
# Hugo_Symbol                              ...
# A1BG             307.4937       87.5786  ...     1507.1099      452.4033
# A1BG-AS1         121.0795       66.0327  ...      317.9009      352.0115
#
#              TCGA-LL-A5YO  TCGA-LL-A5YP  TCGA-LQ-A4E4  TCGA-MS-A51U  \
# Hugo_Symbol
# A1BG             295.5528      136.0353      498.7862      362.5874
# A1BG-AS1         159.2180       63.2459      250.2883      291.5545
#
#              TCGA-OL-A66H  TCGA-OL-A66I  TCGA-OL-A66J  TCGA-OL-A66K
# Hugo_Symbol
# A1BG              51.2469      207.2697      267.0482      422.2195
# A1BG-AS1          54.4412      167.8665      174.9752      227.4997
#
# [2 rows x 817 columns]

# %% [markdown]
# #### Proteomic Data

# %%
brca_proteomics = pd.read_excel(io=file_brca_proteomics, sheet_name="Global-Proteome-G3", engine='openpyxl')
print('Dimensions: ', brca_proteomics.shape)
brca_proteomics[:2]
# Out:
# Dimensions:  (12553, 95)
#   accession_number  numITRAQExperimentsProteinObserved  \
# 0        NP_958782                                  37
# 1        NP_958785                                  37
#
#    numSpectraProteinObserved  protein_mw species accession_numbers  \
# 0                      43425    533778.0   Human         NP_958782
# 1                      42994    518637.5   Human         NP_958785
#
#    numPepsUnique  scoreUnique  total percent Coverage across all experiments  \
# 0            678     11158.42                                           89.1
# 1            670     11042.11                                           90.0
#
#    subgroupNum  ... AO-A12B.34TCGA A2-A0SW.35TCGA  AO-A0JL.35TCGA  \
# 0          1.1  ...      -0.963904      -0.487772        -0.10668
# 1          1.2  ...      -0.938210      -0.487772        -0.10668
#
#    BH-A0BV.35TCGA  A2-A0YM.36TCGA  BH-A0C7.36TCGA  A2-A0SX.36TCGA  \
# 0       -0.065838        0.655850       -0.552212       -0.398560
# 1       -0.055893        0.658143       -0.547749       -0.392601
#
#    263d3f-I.CPTAC  blcdb9-I.CPTAC  c4155b-C.CPTAC
# 0        0.598585       -0.191285        0.566975
# 1        0.606697       -0.183918        0.578702
#
# [2 rows x 95 columns]

# %%
brca_proteomics[['Name', 'geneName']].head(3)
# Out:
#                  Name geneName
# 0   plectin isoform 1     PLEC
# 1  plectin isoform 1g      NaN
# 2  plectin isoform 1a     PLEC

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Note:</b> Since some proteins contain NaN in the geneName column although other isoforms of it exists with correct geneName, proteomics data needs to be processed to fill in the NaN values with the appropriate geneName
# </div>

# %%
#split based on the name and then identify the right geneNames for each protein record
brca_proteomics.loc[:, 'modifiedName'] = brca_proteomics['Name'].str.split('isoform').str[0] 

brca_proteomics['geneName'] = brca_proteomics.groupby(['modifiedName'])['geneName'] \
                                             .apply(lambda x: x.ffill().bfill())

# #Even after filling if there exists NaN values for gene - we drop them
brca_proteomics.dropna(subset=['geneName'], inplace=True)
brca_proteomics = brca_proteomics.groupby(['geneName']).mean()

# Modifying sample names to suit the samples in transcriptomic data
brca_proteomics.columns = [i.replace('.', '-') for i in brca_proteomics.columns]
brca_proteomics = brca_proteomics.loc[:, brca_proteomics.columns.str.contains('TCGA')]
brca_proteomics = brca_proteomics.rename(columns = lambda x : 'TCGA-' + str(x)[:7])
# Aggregate the duplicated columns present
brca_proteomics = brca_proteomics.groupby(brca_proteomics.columns, axis=1).mean()

print("Null values count: ", brca_proteomics.isnull().sum().sum())
brca_proteomics[:2]
# Out:
# Null values count:  80573
#           TCGA-A2-A0CM  TCGA-A2-A0D2  TCGA-A2-A0EQ  TCGA-A2-A0EV  \
# geneName
# A1BG         -0.899882     -0.105400     -0.380704      1.699253
# A2BP1         0.911162      0.882545     -0.874399     -2.084358
#
#           TCGA-A2-A0EX  TCGA-A2-A0EY  TCGA-A2-A0SW  TCGA-A2-A0SX  \
# geneName
# A1BG         -0.390673      1.849433      1.560915      2.369127
# A2BP1         1.796662     -0.578121      1.506240     -0.520707
#
#           TCGA-A2-A0T3  TCGA-A2-A0T6  ...  TCGA-C8-A12Z  TCGA-C8-A130  \
# geneName                              ...
# A1BG         -0.003410      2.519514  ...      1.775668      0.850687
# A2BP1         0.120195     -1.671573  ...     -1.859222      1.008120
#
#           TCGA-C8-A131  TCGA-C8-A134  TCGA-C8-A135  TCGA-C8-A138  \
# geneName
# A1BG         -0.294419      0.320314      2.185114     -2.018457
# A2BP1         0.737591      1.945039     -2.473849      0.329426
#
#           TCGA-D8-A142  TCGA-E2-A154  TCGA-E2-A158  TCGA-E2-A15A
# geneName
# A1BG          1.539879      1.856193     -1.987341     -1.277926
# A2BP1         0.957906      0.520191      0.291579     -2.101058
#
# [2 rows x 77 columns]

# %%
assert len(brca_proteomics.columns[brca_proteomics.columns.duplicated()]) == 0, \
       "columns contain duplicates"

# %%
brca_proteomics_processed = standardised_pipeline_utils.process(brca_proteomics)
brca_proteomics_processed[:2]
# Out:
# Dimensions:  (8052, 77)
#           TCGA-A2-A0CM  TCGA-A2-A0D2  TCGA-A2-A0EQ  TCGA-A2-A0EV  \
# geneName
# A1BG         -0.899882     -0.105400     -0.380704      1.699253
# A2BP1         0.911162      0.882545     -0.874399     -2.084358
#
#           TCGA-A2-A0EX  TCGA-A2-A0EY  TCGA-A2-A0SW  TCGA-A2-A0SX  \
# geneName
# A1BG         -0.390673      1.849433      1.560915      2.369127
# A2BP1         1.796662     -0.578121      1.506240     -0.520707
#
#           TCGA-A2-A0T3  TCGA-A2-A0T6  ...  TCGA-C8-A12Z  TCGA-C8-A130  \
# geneName                              ...
# A1BG         -0.003410      2.519514  ...      1.775668      0.850687
# A2BP1         0.120195     -1.671573  ...     -1.859222      1.008120
#
#           TCGA-C8-A131  TCGA-C8-A134  TCGA-C8-A135  TCGA-C8-A138  \
# geneName
# A1BG         -0.294419      0.320314      2.185114     -2.018457
# A2BP1         0.737591      1.945039     -2.473849      0.329426
#
#           TCGA-D8-A142  TCGA-E2-A154  TCGA-E2-A158  TCGA-E2-A15A
# geneName
# A1BG          1.539879      1.856193     -1.987341     -1.277926
# A2BP1         0.957906      0.520191      0.291579     -2.101058
#
# [2 rows x 77 columns]

# %%
transcriptomic_samples['BrCa (2016)'] = brca_transcriptomics_processed.shape[1]
proteomic_samples['BrCa (2016)'] = brca_proteomics_processed.shape[1]

# %%
brca_transcriptomics_processed, brca_proteomics_processed =  standardised_pipeline_utils.match_proteins_samples( \
                                                                                brca_transcriptomics_processed, 
                                                                                brca_proteomics_processed)
# Out:
# Number of common proteins:  7283
# Number of common samples:  59

# %%
common_samples['BrCa (2016)'] = brca_transcriptomics_processed.shape[1]
common_genes['BrCa (2016)'] = brca_transcriptomics_processed.shape[0]

# %%
correlation_brca = standardised_pipeline_utils.correlate_genewise(brca_transcriptomics_processed, 
                                                                  brca_proteomics_processed, 'BrCa (2016)')
# Out:
# Median Spearman Correlation:  0.4175

# %% [markdown]
# <a id="Ovarian_Cancer"></a>
# ### 3. Ovarian Cancer

# %% [markdown]
# #### Transcriptomic Data

# %%
ovca_transcriptomics = pd.read_csv(file_ovca_transcriptomics, sep="\t", low_memory=False)
print('Dimensions: ', ovca_transcriptomics.shape)
ovca_transcriptomics[:2]
# Out:
# Dimensions:  (18633, 595)
#        Hybridization REF TCGA-01-0628-11A-01R-0361-03  \
# 0  Composite Element REF                       Signal
# 1               C9orf152             5.68406070638714
#
#   TCGA-01-0630-11A-01R-0361-03 TCGA-01-0631-11A-01R-0361-03  \
# 0                       Signal                       Signal
# 1             5.74059738582655             5.37909487049308
#
#   TCGA-01-0633-11A-01R-0361-03 TCGA-01-0636-11A-01R-0361-03  \
# 0                       Signal                       Signal
# 1             5.02811262452816             4.90491745435555
#
#   TCGA-01-0637-11A-01R-0361-03 TCGA-01-0639-11A-01R-0361-03  \
# 0                       Signal                       Signal
# 1             5.91024526125034             6.03056527156875
#
#   TCGA-01-0642-11A-02R-0361-03 TCGA-04-1331-01A-01R-0435-03  ...  \
# 0                       Signal                       Signal  ...
# 1             5.87840655167558              5.1293974840562  ...
#
#   TCGA-61-2104-01A-01R-0669-03 TCGA-61-2109-01A-01R-0669-03  \
# 0                       Signal                       Signal
# 1             4.46343743805034             4.53738193913162
#
#   TCGA-61-2110-01A-01R-0669-03 TCGA-61-2111-01A-01R-0669-03  \
# 0                       Signal                       Signal
# 1             4.06865889851126             4.58072953660696
#
#   TCGA-61-2113-01A-01R-0669-03 TCGA-61-2610-02A-01R-1140-03  \
# 0                       Signal                       Signal
# 1             3.64353233073353             4.85965771708381
#
#   TCGA-61-2611-02A-01R-1140-03 TCGA-61-2612-01A-01R-1140-03  \
# 0                       Signal                       Signal
# 1             3.69981049486697             4.68639184341207
#
#   TCGA-61-2613-01A-01R-1140-03 TCGA-61-2614-01A-01R-1140-03
# 0                       Signal                       Signal
# 1             3.98064149167257             4.12777538628098
#
# [2 rows x 595 columns]

# %%
ovca_transcriptomics.drop(ovca_transcriptomics.index[0], inplace=True)
ovca_transcriptomics = preprocess(ovca_transcriptomics, 'Hybridization REF', [])
# Out:
# Dimensions:  (18632, 594)
# Null values count:  0

# %%
assert len(ovca_transcriptomics.columns[ovca_transcriptomics.columns.duplicated()]) != 0, "columns contain no duplicates"

# %%
ovca_transcriptomics = ovca_transcriptomics.loc[:, ~ovca_transcriptomics.columns.duplicated(keep='first')]

# %%
ovca_transcriptomics_processed = standardised_pipeline_utils.process(ovca_transcriptomics)
ovca_transcriptomics_processed[:2]
# Out:
# Dimensions:  (18632, 579)
#                    TCGA-01-0628  TCGA-01-0630  TCGA-01-0631  TCGA-01-0633  \
# Hybridization REF
# 15E1.2                 8.518316      7.370906      7.708458      7.786219
# 2'-PDE                 6.252983      6.297369      6.206035      6.278075
#
#                    TCGA-01-0636  TCGA-01-0637  TCGA-01-0639  TCGA-01-0642  \
# Hybridization REF
# 15E1.2                 8.224809      7.956135      7.197224      7.949850
# 2'-PDE                 6.339588      6.165869      6.159611      6.257575
#
#                    TCGA-04-1331  TCGA-04-1332  ...  TCGA-61-2104  \
# Hybridization REF                              ...
# 15E1.2                 8.704958      8.882890  ...      8.731404
# 2'-PDE                 6.264530      6.662592  ...      6.576362
#
#                    TCGA-61-2109  TCGA-61-2110  TCGA-61-2111  TCGA-61-2113  \
# Hybridization REF
# 15E1.2                 9.531594      8.583059      8.847043      8.976926
# 2'-PDE                 6.345743      7.163527      6.374608      6.481556
#
#                    TCGA-61-2610  TCGA-61-2611  TCGA-61-2612  TCGA-61-2613  \
# Hybridization REF
# 15E1.2                 8.046281      9.136807      8.983845      9.509617
# 2'-PDE                 6.845093      6.108022      6.476601      6.654893
#
#                    TCGA-61-2614
# Hybridization REF
# 15E1.2                 9.763647
# 2'-PDE                 6.042050
#
# [2 rows x 579 columns]

# %% [markdown]
# #### Proteomic Data

# %%
ovca_proteomics = pd.read_excel(io=file_ovca_proteomics, sheet_name="FullOvarianProteomeData", engine='openpyxl')
print('Dimensions: ', ovca_proteomics.shape)
ovca_proteomics[:2]
# Out:
# Dimensions:  (9600, 208)
#   refseq_peptide hgnc_symbol  PNNL-TCGA-09-1664  PNNL-TCGA-13-1484  \
# 0      NP_000005         A2M            -0.0581             -0.688
# 1      NP_000007       ACADM            -0.1040              0.404
#
#    PNNL-TCGA-13-1488  PNNL-TCGA-13-1489  PNNL-TCGA-13-1494  PNNL-TCGA-13-1495  \
# 0             0.5180             -0.432              0.333              0.109
# 1             0.0714              0.272             -0.369              0.175
#
#    PNNL-TCGA-13-1499  PNNL-TCGA-13-2071  ...  JHU-TCGA-61-1911  \
# 0             -1.230              0.172  ...          0.265750
# 1             -0.295             -0.425  ...          0.073225
#
#    JHU-TCGA-61-1914  JHU-TCGA-61-1915  JHU-TCGA-61-1918  JHU-TCGA-61-1995  \
# 0         -0.688250         -0.071250         -0.767250         -0.821250
# 1         -0.326775         -1.069775         -0.383775          0.105225
#
#    JHU-TCGA-61-2008  JHU-TCGA-61-2087  JHU-TCGA-61-2088  JHU-TCGA-61-2094  \
# 0         -0.360550         -1.022250         -1.172250         -0.132250
# 1          0.365225         -0.277775          0.401225          0.056225
#
#    JHU-TCGA-61-2613
# 0          1.165750
# 1         -0.372775
#
# [2 rows x 208 columns]

# %%
# Clean data
ovca_proteomics = ovca_proteomics.set_index('hgnc_symbol').drop('refseq_peptide', axis=1)
ovca_proteomics.columns = ['-'.join(index) for index in ovca_proteomics.columns.str.split('-').str[1:4]]
# taking mean of the replicates the replicates 
ovca_proteomics = ovca_proteomics.groupby(ovca_proteomics.columns, axis=1).mean()
# taking mean of the isoforms 
ovca_proteomics = ovca_proteomics.groupby(ovca_proteomics.index).mean()

# %%
assert len(ovca_proteomics.columns[ovca_proteomics.columns.duplicated()]) == 0, "columns contain duplicates"

# %%
ovca_proteomics_processed = standardised_pipeline_utils.process(ovca_proteomics)
ovca_proteomics_processed[:2]
# Out:
# Dimensions:  (6627, 174)
#              TCGA-09-1664  TCGA-09-2056  TCGA-13-1404  TCGA-13-1409  \
# hgnc_symbol
# A1BG             0.316850      -0.63230      -1.01930      -0.69730
# A2M             -0.138175       0.00675      -0.86525      -0.98125
#
#              TCGA-13-1410  TCGA-13-1482  TCGA-13-1483  TCGA-13-1484  \
# hgnc_symbol
# A1BG             -0.42900      -0.42700      -0.40200        -1.060
# A2M              -0.00425      -0.46865      -1.12625        -0.688
#
#              TCGA-13-1485  TCGA-13-1487  ...  TCGA-61-1919  TCGA-61-1995  \
# hgnc_symbol                              ...
# A1BG             -0.21430      -0.64430  ...      -0.00193     -0.122350
# A2M              -0.58425      -1.38325  ...      -0.00360     -0.706125
#
#              TCGA-61-2008  TCGA-61-2087  TCGA-61-2088  TCGA-61-2094  \
# hgnc_symbol
# A1BG             0.634850      -1.11530      -0.83830      -0.06730
# A2M             -0.549775      -1.02225      -1.17225      -0.13225
#
#              TCGA-61-2095  TCGA-61-2096  TCGA-61-2612  TCGA-61-2613
# hgnc_symbol
# A1BG                0.635         1.910        0.0689       0.90970
# A2M                 0.910         0.353        0.3500       1.16575
#
# [2 rows x 174 columns]

# %%
transcriptomic_samples['Ovarian'] = ovca_transcriptomics_processed.shape[1]
proteomic_samples['Ovarian'] = ovca_proteomics_processed.shape[1]

# %%
ovca_transcriptomics_processed, ovca_proteomics_processed =  standardised_pipeline_utils.match_proteins_samples( \
                                                                                ovca_transcriptomics_processed, 
                                                                                ovca_proteomics_processed)
# Out:
# Number of common proteins:  5841
# Number of common samples:  174

# %%
common_samples['Ovarian'] = ovca_transcriptomics_processed.shape[1]
common_genes['Ovarian'] = ovca_transcriptomics_processed.shape[0]

# %%
correlation_ovca = standardised_pipeline_utils.correlate_genewise(ovca_transcriptomics_processed, 
                                                                   ovca_proteomics_processed, 'Ovarian')
# Out:
# Median Spearman Correlation:  0.4121

# %% [markdown]
# <a id="Colon_Cancer"></a>
# ### 4. Colon Cancer

# %% [markdown]
# #### Transcriptomic Data

# %%
colon_transcriptomics = pd.read_csv(file_colon_transcriptomics, sep='\t',  low_memory=False)
print('Dimensions: ', colon_transcriptomics.shape)
colon_transcriptomics[:2]
# Out:
# Dimensions:  (13482, 107)
#   attrib_name  01CO001  01CO005  01CO006  01CO008  01CO013  01CO014  01CO015  \
# 0        A1CF  10.1984  10.1586   9.2119  10.7322   9.7160   9.5177   9.6275
# 1         A2M  13.8117  12.6434  15.0040  13.9284  12.9963  11.8700  13.0274
#
#    01CO019  01CO022  ...  20CO001  20CO003  20CO004  20CO007  21CO006  \
# 0   9.5736   4.8580  ...   8.5078   2.5850  10.1408   9.0688   9.2336
# 1  12.5637  11.6234  ...  14.2033  13.7171  11.3078  12.7292  12.9123
#
#    21CO007  22CO004  22CO006  24CO005  27CO004
# 0  10.0768  10.9293   9.2432   8.6546   9.8025
# 1  13.4762  12.6131  14.2620  13.0250  13.1139
#
# [2 rows x 107 columns]

# %%
colon_transcriptomics = preprocess(colon_transcriptomics, index_col='attrib_name')
# Out:
# Dimensions:  (13482, 106)
# Null values count:  0

# %%
assert len(colon_transcriptomics.columns[colon_transcriptomics.columns.duplicated()]) == 0, "columns contain duplicates"

# %%
colon_transcriptomics_processed = standardised_pipeline_utils.process(colon_transcriptomics)
colon_transcriptomics_processed[:2]
# Out:
# Dimensions:  (13448, 106)
#              01CO001  01CO005  01CO006  01CO008  01CO013  01CO014  01CO015  \
# attrib_name
# A1CF         10.1984  10.1586   9.2119  10.7322   9.7160   9.5177   9.6275
# A2M          13.8117  12.6434  15.0040  13.9284  12.9963  11.8700  13.0274
#
#              01CO019  01CO022  05CO002  ...  20CO001  20CO003  20CO004  \
# attrib_name                             ...
# A1CF          9.5736   4.8580   9.2432  ...   8.5078   2.5850  10.1408
# A2M          12.5637  11.6234  15.3414  ...  14.2033  13.7171  11.3078
#
#              20CO007  21CO006  21CO007  22CO004  22CO006  24CO005  27CO004
# attrib_name
# A1CF          9.0688   9.2336  10.0768  10.9293   9.2432   8.6546   9.8025
# A2M          12.7292  12.9123  13.4762  12.6131  14.2620  13.0250  13.1139
#
# [2 rows x 106 columns]

# %% [markdown]
# #### Proteomic Data

# %%
colon_proteomics = pd.read_csv(file_colon_proteomics, sep='\t')
print('Dimensions: ', colon_proteomics.shape)
colon_proteomics[:2]
# Out:
# Dimensions:  (6422, 97)
#   attrib_name  01CO005  01CO006  01CO008  01CO013  01CO014  01CO015  01CO019  \
# 0        A1BG   -1.672  -2.1500   -1.786   -2.115   -1.793   -2.526   -1.441
# 1        A1CF   -0.340  -0.3476   -0.124   -0.197   -0.730      NaN   -0.103
#
#    01CO022  05CO002  ...  20CO001  20CO003  20CO004  20CO006  20CO007  \
# 0    1.047   -1.878  ...    0.297    0.005   -3.390  -1.6480    -1.72
# 1   -1.126    0.507  ...   -0.097   -1.693    0.985   0.9395      NaN
#
#    21CO006  21CO007  22CO004  22CO006  27CO004
# 0    0.038   -1.952  -1.3342   -0.069  -2.6020
# 1   -0.877    0.777   0.1120   -0.519   0.1017
#
# [2 rows x 97 columns]

# %%
colon_proteomics = preprocess(colon_proteomics, index_col='attrib_name')
# Out:
# Dimensions:  (6422, 96)
# Null values count:  64560

# %%
assert len(colon_proteomics.columns[colon_proteomics.columns.duplicated()]) == 0, "columns contain duplicates"

# %%
colon_proteomics_processed = standardised_pipeline_utils.process(colon_proteomics)
colon_proteomics_processed[:2]
# Out:
# Dimensions:  (5152, 96)
#              01CO005  01CO006  01CO008  01CO013  01CO014  01CO015  01CO019  \
# attrib_name
# A1BG          -1.672  -2.1500   -1.786   -2.115   -1.793   -2.526   -1.441
# A1CF          -0.340  -0.3476   -0.124   -0.197   -0.730      NaN   -0.103
#
#              01CO022  05CO002  05CO003  ...  20CO001  20CO003  20CO004  \
# attrib_name                             ...
# A1BG           1.047   -1.878   -0.294  ...    0.297    0.005   -3.390
# A1CF          -1.126    0.507   -1.657  ...   -0.097   -1.693    0.985
#
#              20CO006  20CO007  21CO006  21CO007  22CO004  22CO006  27CO004
# attrib_name
# A1BG         -1.6480    -1.72    0.038   -1.952  -1.3342   -0.069  -2.6020
# A1CF          0.9395      NaN   -0.877    0.777   0.1120   -0.519   0.1017
#
# [2 rows x 96 columns]

# %%
transcriptomic_samples['Colon'] = colon_transcriptomics_processed.shape[1]
proteomic_samples['Colon'] = colon_proteomics_processed.shape[1]

# %%
colon_transcriptomics_processed, colon_proteomics_processed =  standardised_pipeline_utils.match_proteins_samples( \
                                                                                colon_transcriptomics_processed, 
                                                                                colon_proteomics_processed)
# Out:
# Number of common proteins:  4970
# Number of common samples:  95

# %%
common_samples['Colon'] = colon_transcriptomics_processed.shape[1]
common_genes['Colon'] = colon_transcriptomics_processed.shape[0]

# %%
correlation_colon = standardised_pipeline_utils.correlate_genewise(colon_transcriptomics_processed, 
                                                                    colon_proteomics_processed, 'Colon')
# Out:
# Median Spearman Correlation:  0.2702

# %%
correlation_combined = pd.concat([correlation_crc, correlation_brca, correlation_ovca, correlation_colon], axis=1)
correlation_combined.to_csv(file_tumour_correlation)
correlation_combined[:2]
# Out:
#       CRC (2014)  BrCa (2016)   Ovarian     Colon
# A1BG    0.123133    -0.093805 -0.078889       NaN
# A2M    -0.037595     0.118235  0.191865 -0.026288

# %%
def dataframe_from_dict(*dict_args):
    dataframe = pd.DataFrame.from_dict(dict_args[0], orient='index')
    for i in range(1, len(dict_args)):
        dataframe = pd.concat([dataframe, pd.DataFrame.from_dict(dict_args[i], orient='index')], axis=1)
    dataframe.reset_index(inplace=True)
    dataframe.columns=['Data', '# Samples in Trancriptomic Data', '# Samples in Proteomic Data', 
                       '# Common Samples', '# Common Proteins']
    return dataframe.set_index('Data')

sample_data = dataframe_from_dict(transcriptomic_samples, proteomic_samples, common_samples, common_genes)
sample_data.to_csv(file_samples_info)
sample_data
# Out:
#              # Samples in Trancriptomic Data  # Samples in Proteomic Data  \
# Data
# CRC (2014)                               244                           90
# BrCa (2016)                              817                           77
# Ovarian                                  579                          174
# Colon                                    106                           96
#
#              # Common Samples  # Common Proteins
# Data
# CRC (2014)                 77               3238
# BrCa (2016)                59               7283
# Ovarian                   174               5841
# Colon                      95               4970
